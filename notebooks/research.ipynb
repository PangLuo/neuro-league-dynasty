# %%
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
runner = InMemoryRunner(agent=research_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# ResearchAgent > Recent advancements in quantum computing are poised to significantly enhance Artificial Intelligence (AI) capabilities, ushering in an era of "Quantum AI." This fusion promises to overcome current AI limitations, enabling faster training, improved optimization, and the ability to tackle previously intractable problems.
#
# Key advancements include:
#
# *   **Enhanced Computational Power:** Quantum computers utilize qubits, which can exist in multiple states simultaneously due to superposition. This allows them to process vast datasets and explore numerous solutions concurrently, far exceeding the capabilities of classical computers. This is crucial for AI, which often grapples with enormous datasets and complex computations.
# *   **Improved Hardware and Error Correction:** Significant progress is being made in developing more stable qubits, increasing coherence times, and implementing effective quantum error correction techniques. For instance, Google's Willow chip has demonstrated a significant reduction in error rates with scaling, while Microsoft has achieved breakthroughs in qubit virtualization. These developments are making quantum computers more reliable and practical for real-world applications.
# *   **Hybrid Quantum-Classical Computing:** The near future of Quantum AI is expected to rely on hybrid systems that leverage the strengths of both quantum and classical computers. This approach allows AI to handle general tasks while offloading complex computations to quantum processors.
# *   **Development of Quantum Algorithms:** Researchers are actively developing quantum machine learning (QML) algorithms designed to enhance AI performance. These algorithms can accelerate model training, improve data processing, and optimize complex tasks.
#
# These advancements have profound implications for AI:
#
# *   **Faster AI Model Training:** Quantum computers can drastically speed up the training of AI models, particularly deep learning networks, by performing complex matrix operations more efficiently.
# *   **Enhanced Optimization:** Quantum algorithms like QAOA and VQE can significantly improve AI's optimization capabilities, leading to better fine-tuning of machine learning models and more efficient solutions for complex problems in fields like logistics, finance, and drug discovery.
# *   **Solving Complex Problems:** Quantum AI can enable AI to address challenges that are currently beyond the reach of classical computing, such as molecular simulation for drug discovery and materials science, advanced natural language processing, and more accurate financial modeling.
# *   **Increased Efficiency and Sustainability:** Quantum computing has the potential to make AI more energy-efficient, addressing concerns about the significant energy consumption of current AI models.
#
# While Quantum AI is still in its early stages, the rapid pace of innovation suggests that it will play a transformative role in the future of artificial intelligence, driving breakthroughs across various industries.

# %%
response
# Out:
# [Event(model_version='gemini-2.5-flash-lite', content=Content(
#    parts=[
#      Part(
#        text="""Recent advancements in quantum computing are poised to significantly enhance Artificial Intelligence (AI) capabilities, ushering in an era of "Quantum AI." This fusion promises to overcome current AI limitations, enabling faster training, improved optimization, and the ability to tackle previously intractable problems.
#
#  Key advancements include:
#
#  *   **Enhanced Computational Power:** Quantum computers utilize qubits, which can exist in multiple states simultaneously due to superposition. This allows them to process vast datasets and explore numerous solutions concurrently, far exceeding the capabilities of classical computers. This is crucial for AI, which often grapples with enormous datasets and complex computations.
#  *   **Improved Hardware and Error Correction:** Significant progress is being made in developing more stable qubits, increasing coherence times, and implementing effective quantum error correction techniques. For instance, Google's Willow chip has demonstrated a significant reduction in error rates with scaling, while Microsoft has achieved breakthroughs in qubit virtualization. These developments are making quantum computers more reliable and practical for real-world applications.
#  *   **Hybrid Quantum-Classical Computing:** The near future of Quantum AI is expected to rely on hybrid systems that leverage the strengths of both quantum and classical computers. This approach allows AI to handle general tasks while offloading complex computations to quantum processors.
#  *   **Development of Quantum Algorithms:** Researchers are actively developing quantum machine learning (QML) algorithms designed to enhance AI performance. These algorithms can accelerate model training, improve data processing, and optimize complex tasks.
#
#  These advancements have profound implications for AI:
#
#  *   **Faster AI Model Training:** Quantum computers can drastically speed up the training of AI models, particularly deep learning networks, by performing complex matrix operations more efficiently.
#  *   **Enhanced Optimization:** Quantum algorithms like QAOA and VQE can significantly improve AI's optimization capabilities, leading to better fine-tuning of machine learning models and more efficient solutions for complex problems in fields like logistics, finance, and drug discovery.
#  *   **Solving Complex Problems:** Quantum AI can enable AI to address challenges that are currently beyond the reach of classical computing, such as molecular simulation for drug discovery and materials science, advanced natural language processing, and more accurate financial modeling.
#  *   **Increased Efficiency and Sustainability:** Quantum computing has the potential to make AI more energy-efficient, addressing concerns about the significant energy consumption of current AI models.
#
#  While Quantum AI is still in its early stages, the rapid pace of innovation suggests that it will play a transformative role in the future of artificial intelligence, driving breakthroughs across various industries."""
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=GroundingMetadata(
#    grounding_chunks=[
#      GroundingChunk(
#        web=GroundingChunkWeb(
#          title='vivatechnology.com',
#          uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGRO8_sgDQvVMNFUhXqVZzbhTJXk4rUMKLuyZtgF3ZBcUUj5Dfqg2HAF5AfKRaqO6UpAnP8d9Qq7o05uqeIdffCUJ0EsWNbV1oblVivM5J3XD7LTjGN2nHz0IV8LP8SL0gC0sJCykx4qyQF46pgYJDz9Qcsh9DJ8pF5ap0e67hUh0ZOX9XoJSYW3ajJCu_rlg0miTs='
#        )
#      ),
#      GroundingChunk(
#        web=GroundingChunkWeb(
#          title='insideglobaltech.com',
#          uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGrsKT-KQphY8Al99vQN9IUo1jxHPYBGNe298xslfuJrjf9zDhEyhXVQPerVYmzJS7OKIVF3fZjWyz80R-xtKRs_0U_3CLCFUgEMjCuz_EPF82_LGXePQ3UouiU-MJ8TTzWcdUAe2a0pHSkt5a1IAn0InzzhpHwcBNtFtkJw1qS3Qq0WN4bqtDH3giBqLS22peLEgNKcQcmEVZXyPTRWaKciwLjZq0='
#        )
#      ),
#      GroundingChunk(
#        web=GroundingChunkWeb(
#          title='meetiqm.com',
#          uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEAdEWUgG_n1tqAWJrD4nMDUXMWknZf9956Y0KCM7SSIn6MYZy3qUqIbth8vG0MBjTFiHHD2wbBH9kdQ7SLXQzbveX0wVBZuLq4M8UC8EQWJsy6AVQykEPjBlqB09UdUDPEfTwjelHkMyaF3y86LYE6_3e-V6eRY6lRBDxtBKkVITdZMA=='
#        )
#      ),
#      GroundingChunk(
#        web=GroundingChunkWeb(
#          title='medium.com',
#          uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEKEWn4c9nhc6EUryuF60vr6QArxF0X-t66SWkTvW8wUtyhHJ0tW_ysBlQXaPwNT9y3dwyJi4XEHz9LQuk2M6hIBmAfNMGDUVWHLeJmm4Tl8VgT2CTRtbW_SCi2A8WDorya-pdhiloAYwtC7ZVVCrqnK9AXILpxT5EhPv1FzAMn7vBF6w4JPaYrDCEM0W8zCikVlTymgAPeSYr62wHmmbufaHyeZFjm4bRBzhYKNvPZyICNzdCYUA=='
#        )
#      ),
#      GroundingChunk(
#        web=GroundingChunkWeb(
#          title='thequantuminsider.com',
#          uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEqVxjeRKMNbNDK3VT48yJPVIhhEmk_a7SvZf3qV13C5WQXIt0x9IIgkovcmW6UAPfNcJMGsR-zU2KJmAFq_53WcovyIv-GqJv41FtdqjxiSClnxc1qC1DZbr0wwakH9xR_qzb49t2KEMlzq0qM7gsHrR2ptCDEvJUFR418KK_93K1D72b1W11bqF_T_gQV4Dy6YPK_JDpIWDsvj8v0oXJ_MgDmqHYDYjcCSZ6E03dkf_HgWfHA0hd-kH88GVBayovudLUP'
#        )
#      ),
#      <... 6 more items ...>,
#    ],
#    grounding_supports=[
#      GroundingSupport(
#        grounding_chunk_indices=[
#          0,
#          1,
#        ],
#        segment=Segment(
#          end_index=727,
#          start_index=635,
#          text='This is crucial for AI, which often grapples with enormous datasets and complex computations'
#        )
#      ),
#      GroundingSupport(
#        grounding_chunk_indices=[
#          2,
#          3,
#          4,
#          5,
#        ],
#        segment=Segment(
#          end_index=1109,
#          start_index=938,
#          text="For instance, Google's Willow chip has demonstrated a significant reduction in error rates with scaling, while Microsoft has achieved breakthroughs in qubit virtualization"
#        )
#      ),
#      GroundingSupport(
#        grounding_chunk_indices=[
#          2,
#          3,
#        ],
#        segment=Segment(
#          end_index=1214,
#          start_index=1111,
#          text='These developments are making quantum computers more reliable and practical for real-world applications'
#        )
#      ),
#      GroundingSupport(
#        grounding_chunk_indices=[
#          2,
#          1,
#        ],
#        segment=Segment(
#          end_index=1504,
#          start_index=1397,
#          text='This approach allows AI to handle general tasks while offloading complex computations to quantum processors'
#        )
#      ),
#      GroundingSupport(
#        grounding_chunk_indices=[
#          6,
#          1,
#          7,
#        ],
#        segment=Segment(
#          end_index=1762,
#          start_index=1663,
#          text='These algorithms can accelerate model training, improve data processing, and optimize complex tasks'
#        )
#      ),
#      <... 5 more items ...>,
#    ],
#    search_entry_point=SearchEntryPoint(
#      rendered_content="""<style>
#  .container {
#    align-items: center;
#    border-radius: 8px;
#    display: flex;
#    font-family: Google Sans, Roboto, sans-serif;
#    font-size: 14px;
#    line-height: 20px;
#    padding: 8px 12px;
#  }
#  .chip {
#    display: inline-block;
#    border: solid 1px;
#    border-radius: 16px;
#    min-width: 14px;
#    padding: 5px 16px;
#    text-align: center;
#    user-select: none;
#    margin: 0 8px;
#    -webkit-tap-highlight-color: transparent;
#  }
#  .carousel {
#    overflow: auto;
#    scrollbar-width: none;
#    white-space: nowrap;
#    margin-right: -12px;
#  }
#  .headline {
#    display: flex;
#    margin-right: 4px;
#  }
#  .gradient-container {
#    position: relative;
#  }
#  .gradient {
#    position: absolute;
#    transform: translate(3px, -9px);
#    height: 36px;
#    width: 9px;
#  }
#  @media (prefers-color-scheme: light) {
#    .container {
#      background-color: #fafafa;
#      box-shadow: 0 0 0 1px #0000000f;
#    }
#    .headline-label {
#      color: #1f1f1f;
#    }
#    .chip {
#      background-color: #ffffff;
#      border-color: #d2d2d2;
#      color: #5e5e5e;
#      text-decoration: none;
#    }
#    .chip:hover {
#      background-color: #f2f2f2;
#    }
#    .chip:focus {
#      background-color: #f2f2f2;
#    }
#    .chip:active {
#      background-color: #d8d8d8;
#      border-color: #b6b6b6;
#    }
#    .logo-dark {
#      display: none;
#    }
#    .gradient {
#      background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#    }
#  }
#  @media (prefers-color-scheme: dark) {
#    .container {
#      background-color: #1f1f1f;
#      box-shadow: 0 0 0 1px #ffffff26;
#    }
#    .headline-label {
#      color: #fff;
#    }
#    .chip {
#      background-color: #2c2c2c;
#      border-color: #3c4043;
#      color: #fff;
#      text-decoration: none;
#    }
#    .chip:hover {
#      background-color: #353536;
#    }
#    .chip:focus {
#      background-color: #353536;
#    }
#    .chip:active {
#      background-color: #464849;
#      border-color: #53575b;
#    }
#    .logo-light {
#      display: none;
#    }
#    .gradient {
#      background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#    }
#  }
#  </style>
#  <div class="container">
#    <div class="headline">
#      <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#        <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#        <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#        <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#        <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#      </svg>
#      <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#        <circle cx="24" cy="23" fill="#FFF" r="22"/>
#        <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#        <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#        <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#        <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#      </svg>
#      <div class="gradient-container"><div class="gradient"></div></div>
#    </div>
#    <div class="carousel">
#      <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGyXO0Ctz0McKn2cF4BJlJFhAEQZk7F4B_K9T-UD-FDu1LePanVRvHQqWawcuirJ5czJMXdZ6FDS0lApGBnq_UcZLAANM0xXP5aENWJC1U7vzZpJvnvPJUMIFEd-rmkr9X7OKOX6MBgpPSZ9H15louqMPxAl5dmAdZXYmXDf7HC-IcrDOhyU_CNFr9gSNwQSdLCuF3vY4VAoWNZ2DEWtXv_bQhWpn93">how quantum computing can enhance AI</a>
#      <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEsM33yNAeyunF0Re8_oXtC55EhDvuwdSl-cCS7nlfESY6F2Hu7M45KbaNAFhNQBYTFUnkyI1wP_PDsEq0YfvxLA_diaCrHaUtnwqxzKiAP2qTHoTJly7cJwU8_ytXlCCMHBiDEuh68I7AcMRhskvNv1wtOxQZCrmYr23hwRAFdojudydesziCBlOd5HoDBo1IQGOpDdKOiD6N0oETVW53-PNCKjkFsQzCjcSYUJmp9vd99Ikr4DnzU5sPL4w==">latest advancements in quantum computing and impact on AI</a>
#      <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEDQ1ZnfuZUV--uXvQJtJ5VoqtrkA6SVWAzdI3winXXFoeNlYFvsVrIHJ9l7tA7AixM80FlDBaIj3rZK3f3n_Pqu1-kKDXULKMgMbxphvhfOBEzafxVQeY1z-Th57E1hHByrvKcwY8oyKws8PrC9XhAJ-v6qIf6zp1_H3KI_4CEjYY7ML-7LMo8imjAdBAgowkup0yQInwtiioeiR8kqyNPL6L-ObWt4mTJQwU=">quantum computing breakthroughs 2024 2025</a>
#    </div>
#  </div>
#  """
#    ),
#    web_search_queries=[
#      'latest advancements in quantum computing and impact on AI',
#      'quantum computing breakthroughs 2024 2025',
#      'how quantum computing can enhance AI',
#    ]
#  ), partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=547,
#    prompt_token_count=73,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=73
#      ),
#    ],
#    tool_use_prompt_token_count=116,
#    tool_use_prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=116
#      ),
#    ],
#    total_token_count=736
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-65cb9b70-3cd9-42e4-a7ca-d49ba459caa1', author='ResearchAgent', actions=EventActions(skip_summarization=None, state_delta={'research_findings': 'Recent advancements in quantum computing are poised to significantly enhance Artificial Intelligence (AI) capabilities, ushering in an era of "Quantum AI." This fusion promises to overcome current AI limitations, enabling faster training, improved optimization, and the ability to tackle previously intractable problems.\n\nKey advancements include:\n\n*   **Enhanced Computational Power:** Quantum computers utilize qubits, which can exist in multiple states simultaneously due to superposition. This allows them to process vast datasets and explore numerous solutions concurrently, far exceeding the capabilities of classical computers. This is crucial for AI, which often grapples with enormous datasets and complex computations.\n*   **Improved Hardware and Error Correction:** Significant progress is being made in developing more stable qubits, increasing coherence times, and implementing effective quantum error correction techniques. For instance, Google\'s Willow chip has demonstrated a significant reduction in error rates with scaling, while Microsoft has achieved breakthroughs in qubit virtualization. These developments are making quantum computers more reliable and practical for real-world applications.\n*   **Hybrid Quantum-Classical Computing:** The near future of Quantum AI is expected to rely on hybrid systems that leverage the strengths of both quantum and classical computers. This approach allows AI to handle general tasks while offloading complex computations to quantum processors.\n*   **Development of Quantum Algorithms:** Researchers are actively developing quantum machine learning (QML) algorithms designed to enhance AI performance. These algorithms can accelerate model training, improve data processing, and optimize complex tasks.\n\nThese advancements have profound implications for AI:\n\n*   **Faster AI Model Training:** Quantum computers can drastically speed up the training of AI models, particularly deep learning networks, by performing complex matrix operations more efficiently.\n*   **Enhanced Optimization:** Quantum algorithms like QAOA and VQE can significantly improve AI\'s optimization capabilities, leading to better fine-tuning of machine learning models and more efficient solutions for complex problems in fields like logistics, finance, and drug discovery.\n*   **Solving Complex Problems:** Quantum AI can enable AI to address challenges that are currently beyond the reach of classical computing, such as molecular simulation for drug discovery and materials science, advanced natural language processing, and more accurate financial modeling.\n*   **Increased Efficiency and Sustainability:** Quantum computing has the potential to make AI more energy-efficient, addressing concerns about the significant energy consumption of current AI models.\n\nWhile Quantum AI is still in its early stages, the rapid pace of innovation suggests that it will play a transformative role in the future of artificial intelligence, driving breakthroughs across various industries.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch=None, id='c4dab9c7-1d83-4de7-9a92-08e5ff65ab6d', timestamp=1764465097.760721)]

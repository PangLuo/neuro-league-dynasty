# %%
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to find 2-3 pieces of relevant information on the given topic and present the findings.""",
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
runner = InMemoryRunner(agent=research_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# ResearchAgent > Here are a couple of recent advancements in quantum computing and their implications for AI:
#
# 1.  **Improved Quantum Error Correction:** Recent research has focused on developing more robust quantum error correction codes. For instance, advancements in topological quantum computing and surface codes are showing promise in reducing the high error rates that have historically plagued quantum computers. This is crucial because AI algorithms often require high precision and complex calculations.
#
#     *   **Implication for AI:** More reliable quantum computers, due to better error correction, will be able to execute more complex AI algorithms without significant degradation of results. This could unlock the potential for quantum machine learning algorithms to tackle problems that are currently intractable for classical computers, such as advanced pattern recognition in massive datasets, more sophisticated drug discovery simulations, and highly optimized financial modeling.
#
# 2.  **Development of NISQ (Noisy Intermediate-Scale Quantum) Algorithms for AI:** While full fault-tolerant quantum computers are still some way off, researchers are making strides in designing and implementing AI algorithms that can run on current, imperfect NISQ devices. Examples include variational quantum algorithms (VQAs) like the Variational Quantum Eigensolver (VQE) and Quantum Approximate Optimization Algorithm (QAOA) being adapted for machine learning tasks like classification and regression.
#
#     *   **Implication for AI:** The ability to run AI workloads on NISQ hardware means that the synergy between quantum computing and AI could begin sooner than expected. This could lead to "quantum advantage" in specific AI sub-fields even before fault-tolerant machines are available, potentially accelerating the development of hybrid quantum-classical AI models. These models could leverage quantum processors for specific, computationally intensive parts of an AI task, while classical computers handle the rest.

# %%
response
# Out:
# [Event(model_version='gemini-2.5-flash-lite', content=Content(
#    parts=[
#      Part(
#        text="""Here are a couple of recent advancements in quantum computing and their implications for AI:
#
#  1.  **Improved Quantum Error Correction:** Recent research has focused on developing more robust quantum error correction codes. For instance, advancements in topological quantum computing and surface codes are showing promise in reducing the high error rates that have historically plagued quantum computers. This is crucial because AI algorithms often require high precision and complex calculations.
#
#      *   **Implication for AI:** More reliable quantum computers, due to better error correction, will be able to execute more complex AI algorithms without significant degradation of results. This could unlock the potential for quantum machine learning algorithms to tackle problems that are currently intractable for classical computers, such as advanced pattern recognition in massive datasets, more sophisticated drug discovery simulations, and highly optimized financial modeling.
#
#  2.  **Development of NISQ (Noisy Intermediate-Scale Quantum) Algorithms for AI:** While full fault-tolerant quantum computers are still some way off, researchers are making strides in designing and implementing AI algorithms that can run on current, imperfect NISQ devices. Examples include variational quantum algorithms (VQAs) like the Variational Quantum Eigensolver (VQE) and Quantum Approximate Optimization Algorithm (QAOA) being adapted for machine learning tasks like classification and regression.
#
#      *   **Implication for AI:** The ability to run AI workloads on NISQ hardware means that the synergy between quantum computing and AI could begin sooner than expected. This could lead to "quantum advantage" in specific AI sub-fields even before fault-tolerant machines are available, potentially accelerating the development of hybrid quantum-classical AI models. These models could leverage quantum processors for specific, computationally intensive parts of an AI task, while classical computers handle the rest."""
#      ),
#    ],
#    role='model'
#  ), grounding_metadata=None, partial=None, turn_complete=None, finish_reason=<FinishReason.STOP: 'STOP'>, error_code=None, error_message=None, interrupted=None, custom_metadata=None, usage_metadata=GenerateContentResponseUsageMetadata(
#    candidates_token_count=348,
#    prompt_token_count=62,
#    prompt_tokens_details=[
#      ModalityTokenCount(
#        modality=<MediaModality.TEXT: 'TEXT'>,
#        token_count=62
#      ),
#    ],
#    total_token_count=410
#  ), live_session_resumption_update=None, input_transcription=None, output_transcription=None, avg_logprobs=None, logprobs_result=None, cache_metadata=None, citation_metadata=None, invocation_id='e-7b95ee41-0cd8-4e0f-ae14-4c9754b3a9d6', author='ResearchAgent', actions=EventActions(skip_summarization=None, state_delta={'research_findings': 'Here are a couple of recent advancements in quantum computing and their implications for AI:\n\n1.  **Improved Quantum Error Correction:** Recent research has focused on developing more robust quantum error correction codes. For instance, advancements in topological quantum computing and surface codes are showing promise in reducing the high error rates that have historically plagued quantum computers. This is crucial because AI algorithms often require high precision and complex calculations.\n\n    *   **Implication for AI:** More reliable quantum computers, due to better error correction, will be able to execute more complex AI algorithms without significant degradation of results. This could unlock the potential for quantum machine learning algorithms to tackle problems that are currently intractable for classical computers, such as advanced pattern recognition in massive datasets, more sophisticated drug discovery simulations, and highly optimized financial modeling.\n\n2.  **Development of NISQ (Noisy Intermediate-Scale Quantum) Algorithms for AI:** While full fault-tolerant quantum computers are still some way off, researchers are making strides in designing and implementing AI algorithms that can run on current, imperfect NISQ devices. Examples include variational quantum algorithms (VQAs) like the Variational Quantum Eigensolver (VQE) and Quantum Approximate Optimization Algorithm (QAOA) being adapted for machine learning tasks like classification and regression.\n\n    *   **Implication for AI:** The ability to run AI workloads on NISQ hardware means that the synergy between quantum computing and AI could begin sooner than expected. This could lead to "quantum advantage" in specific AI sub-fields even before fault-tolerant machines are available, potentially accelerating the development of hybrid quantum-classical AI models. These models could leverage quantum processors for specific, computationally intensive parts of an AI task, while classical computers handle the rest.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None), long_running_tool_ids=None, branch=None, id='9a07130c-0d65-4afd-ae24-9b59d415b848', timestamp=1764465227.119231)]
